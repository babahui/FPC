# %%
# OCC_Duke training & test

# !python test.py --config_file configs/OCC_Duke/vit_transreid_stride.yml MODEL.DEVICE_ID "('0')" TEST.WEIGHT './FPC_Occ_Duke_reconstruction.pth'
# Out:
# 2023-03-15 15:48:00,256 transreid INFO: Namespace(config_file='configs/OCC_Duke/vit_transreid_stride.yml', opts=['MODEL.DEVICE_ID', "('0')", 'TEST.WEIGHT', './FPC_Occ_Duke_reconstruction.pth'])
# 2023-03-15 15:48:00,256 transreid INFO: Loaded configuration file configs/OCC_Duke/vit_transreid_stride.yml
# 2023-03-15 15:48:00,257 transreid INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   PRETRAIN_PATH: './jx_vit_base_p16_224-80ecf9dd.pth'
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'off'
#   IF_WITH_CENTER: 'no'
#   NAME: 'transformer'
#   NO_MARGIN: True
#   DEVICE_ID: ('3')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [11, 11]
#   SIE_CAMERA: True
#   SIE_COE: 3.0
#   JPM: True
#   RE_ARRANGE: True
#
# INPUT:
#   SIZE_TRAIN: [256, 128]
#   SIZE_TEST: [256, 128]
#   PROB: 0.5 # random horizontal flip
#   RE_PROB: 0.5 # random erasing
#   PADDING: 10
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#
# DATASETS:
# ...
